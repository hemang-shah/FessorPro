# %% [markdown]
# # Contracts

# %%
from ib_async import *
util.startLoop()  # uncomment this line when in a notebook

ib = IB()
ib.connect('127.0.0.1', 7496, clientId=2)  ## 7496 is production , ##7497 is for paper account
# Out:
# <IB connected to 127.0.0.1:7496 clientId=2>
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cafarm; cashfarm; usopt; usfarm; ushmds; secdefil.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: cafarm; cashfarm; usopt; usfarm; ushmds; secdefil.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# ...

# %%
msft=Contract(symbol='MSFT',currency='USD',exchange='SMART',secType='STK')
msft

ib.qualifyContracts(msft)
# Out:
# [Contract(secType='STK', conId=272093, symbol='MSFT', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='MSFT', tradingClass='NMS')]

# %% [markdown]
# Crypto

# %%
ib.qualifyContracts(Crypto('ETH',currency='USD',exchange='PAXOS'))
# Out:
# [Crypto(conId=495759171, symbol='ETH', exchange='PAXOS', currency='USD', localSymbol='ETH.USD', tradingClass='ETH')]

# %%
#Option Contract

ib.qualifyContracts(Option(symbol='SPY',currency='USD',exchange='SMART',lastTradeDateOrContractMonth='20251114',right='C',strike=610))
# Out:
# [Option(conId=819967977, symbol='SPY', lastTradeDateOrContractMonth='20251114', strike=610.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='SPY   251114C00610000', tradingClass='SPY')]
